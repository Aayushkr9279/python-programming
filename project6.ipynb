# %%
import http.server
import socketserver

PORT = 8080
Handler = http.server.SimpleHTTPRequestHandler

with socketserver.TCPServer(("",PORT),Handler) as http:
    print("server running on port",PORT)
    http.serve_forever()
# Out:
# server running on port 8080
# 127.0.0.1 - - [27/Nov/2025 02:04:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2025 02:04:42] code 404, message File not found
# 127.0.0.1 - - [27/Nov/2025 02:04:42] "GET /favicon.ico HTTP/1.1" 404 -
